# %% [markdown]
# <a href="https://colab.research.google.com/github/aadikamble/Letsgrowmore/blob/master/Intermediate_Level_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##DATA SCIENCE INTERN @LETSGROWMORE (LGMVIP)

# %% [markdown]
# Intermediate level
# #Task 1 - Exploratory Data Analysis on Dataset - Terrorism | Dataset_Link - https://drive.google.com/file/d/1luTU7xBvI7QAGPbQMxEHcgKUi9d6UeP_/view

# %% [markdown]
# Author - AADITYA KAMBLE

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Load Dataset**

# %%
data = pd.read_csv('/content/globalterrorismdb_0718dist.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4,31,33,62,76,79,94,96,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970     7.0   2.0        NaN       0.0        NaN     58.0
# 1  1.970000e+11   1970     0.0   0.0        NaN       0.0        NaN    130.0
# 2  1.970010e+11   1970     1.0   0.0        NaN       0.0        NaN    160.0
# 3  1.970010e+11   1970     1.0   0.0        NaN       0.0        NaN     78.0
# 4  1.970010e+11   1970     1.0   0.0        NaN       0.0        NaN    101.0
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic     2.0  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico     1.0  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines     5.0  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece     8.0  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan     4.0  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      0.0       0.0      0.0     0.0      NaN
# 1      0.0       1.0      1.0     1.0      NaN
# 2     -9.0      -9.0      1.0     1.0      NaN
# 3     -9.0      -9.0      1.0     1.0      NaN
# 4     -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
data.tail()
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 18908  1.983050e+11   1983     5.0  27.0        NaN       0.0        NaN
# 18909  1.983050e+11   1983     5.0  27.0        NaN       0.0        NaN
# 18910  1.983050e+11   1983     5.0  27.0        NaN       0.0        NaN
# 18911  1.983050e+11   1983     5.0  27.0        NaN       0.0        NaN
# 18912  1.983050e+11     19     NaN   NaN        NaN       NaN        NaN
#
#        country country_txt  region  ... addnotes scite1 scite2  scite3  \
# 18908    110.0     Lebanon    10.0  ...      NaN    NaN    NaN     NaN
# 18909    110.0     Lebanon    10.0  ...      NaN    NaN    NaN     NaN
# 18910    185.0       Spain     8.0  ...      NaN    NaN    NaN     NaN
# 18911    159.0        Peru     3.0  ...      NaN    NaN    NaN     NaN
# 18912      NaN         NaN     NaN  ...      NaN    NaN    NaN     NaN
#
#        dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 18908      PGIS      1.0       0.0      1.0     1.0      NaN
# 18909      PGIS      1.0       0.0      1.0     1.0      NaN
# 18910      PGIS      0.0       1.0      0.0     1.0      NaN
# 18911      PGIS      0.0       0.0      0.0     0.0      NaN
# 18912       NaN      NaN       NaN      NaN     NaN      NaN
#
# [5 rows x 135 columns]

# %%
data.shape
# Out:
# (18913, 135)

# %%
data.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  1.891300e+04  18913.000000  18912.000000  18912.000000  18912.000000
# mean   1.978589e+11   1978.423360      6.196119     15.231123      0.019088
# std    3.409195e+08     14.651462      3.444949      8.960411      0.136839
# min    1.970000e+11     19.000000      0.000000      0.000000      0.000000
# 25%    1.977040e+11   1977.000000      3.000000      8.000000      0.000000
# 50%    1.979100e+11   1979.000000      6.000000     15.000000      0.000000
# 75%    1.981080e+11   1981.000000      9.000000     23.000000      0.000000
# max    1.983050e+11   1986.000000     12.000000     31.000000      1.000000
#
#             country        region      latitude     longitude   specificity  \
# count  18912.000000  18912.000000  18163.000000  1.816300e+04  18912.000000
# mean     177.526121      5.413758     26.322046 -4.775917e+03      1.289499
# std      166.085051      3.356896     22.541727  6.395025e+05      0.952302
# min        4.000000      1.000000    -45.867889 -8.618590e+07      1.000000
# 25%       69.000000      2.000000     13.692880 -8.688120e+01      1.000000
# 50%      110.000000      5.000000     33.888523 -6.976641e+00      1.000000
# 75%      209.000000      8.000000     43.184040  9.174508e+00      1.000000
# max      605.000000     12.000000     64.837778  1.726362e+02      5.000000
#
#        ...     ransomamt  ransomamtus    ransompaid  ransompaidus  \
# count  ...  4.330000e+02          1.0  9.000000e+01           1.0
# mean   ...  3.788639e+06      20000.0  1.333696e+06           0.0
# std    ...  4.845468e+07          NaN  4.800603e+06           NaN
# min    ...  0.000000e+00      20000.0  0.000000e+00           0.0
# 25%    ...  0.000000e+00      20000.0  0.000000e+00           0.0
# 50%    ...  0.000000e+00      20000.0  7.750000e+04           0.0
# 75%    ...  4.350000e+05      20000.0  7.750000e+05           0.0
# max    ...  1.000000e+09      20000.0  4.100000e+07           0.0
#
#        hostkidoutcome   nreleased       INT_LOG      INT_IDEO      INT_MISC  \
# count      671.000000  510.000000  18912.000000  18912.000000  18912.000000
# mean         2.901639    8.225490     -3.629230     -3.586823      0.250053
# std          1.298396   28.655294      4.528817      4.574413      0.644961
# min          2.000000  -99.000000     -9.000000     -9.000000     -9.000000
# 25%          2.000000    1.000000     -9.000000     -9.000000      0.000000
# 50%          2.000000    1.000000      0.000000      0.000000      0.000000
# 75%          4.000000    2.000000      0.000000      0.000000      1.000000
# max          7.000000  215.000000      1.000000      1.000000      1.000000
#
#             INT_ANY
# count  18912.000000
# mean      -2.611569
# std        4.517983
# min       -9.000000
# 25%       -9.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 79 columns]

# %%
data.corr()
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.223609 -0.079062 -0.003669 -0.060977 -0.334821
# iyear      0.223609  1.000000 -0.089176 -0.003689 -0.061065 -0.334659
# imonth    -0.079062 -0.089176  1.000000  0.013236  0.013371  0.016522
# iday      -0.003669 -0.003689  0.013236  1.000000 -0.006488  0.025129
# extended  -0.060977 -0.061065  0.013371 -0.006488  1.000000 -0.061446
# ...             ...       ...       ...       ...       ...       ...
# nreleased  0.011550  0.011967 -0.038540 -0.018405  0.001410  0.081667
# INT_LOG   -0.050527 -0.050518 -0.005129  0.013197  0.025014  0.192567
# INT_IDEO  -0.054506 -0.054509 -0.003555  0.011646  0.032679  0.184240
# INT_MISC  -0.198305 -0.198508  0.036022  0.016223  0.033392  0.392544
# INT_ANY   -0.138062 -0.138085  0.004690  0.018901  0.030944  0.300686
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# eventid   -0.057875 -0.312291  -0.007762     0.137604  ...   0.011278
# iyear     -0.057475 -0.311739  -0.007629     0.137890  ...   0.011679
# imonth    -0.028435 -0.014441  -0.012477    -0.043823  ...  -0.037475
# iday       0.006345  0.008625  -0.007246    -0.008003  ...   0.003177
# extended  -0.018461 -0.068396   0.001011     0.024547  ...  -0.033162
# ...             ...       ...        ...          ...  ...        ...
# nreleased  0.144892  0.146179   0.195225    -0.044226  ...   0.006771
# INT_LOG    0.108364  0.105703   0.008809    -0.002108  ...   0.038066
# INT_IDEO   0.109795  0.101758   0.008790    -0.003728  ...   0.034730
# INT_MISC   0.216281  0.251999   0.002942    -0.063800  ...  -0.014744
# INT_ANY    0.223539  0.205510   0.010558    -0.045052  ...   0.025086
#
#            ransomamtus  ransompaid  ransompaidus  hostkidoutcome  nreleased  \
# eventid            NaN   -0.126166           NaN        0.080202   0.011550
# iyear              NaN   -0.128501           NaN        0.080041   0.011967
# imonth             NaN    0.202327           NaN        0.015113  -0.038540
# iday               NaN    0.014114           NaN        0.058590  -0.018405
# extended           NaN   -0.135970           NaN       -0.082586   0.001410
# ...                ...         ...           ...             ...        ...
# nreleased          NaN   -0.038965           NaN       -0.162178   1.000000
# INT_LOG            NaN   -0.050077           NaN       -0.093711   0.013475
# INT_IDEO           NaN   -0.045284           NaN       -0.105341   0.011796
# INT_MISC           NaN    0.021537           NaN       -0.000316   0.024506
# INT_ANY            NaN    0.004150           NaN       -0.093288   0.037916
#
#             INT_LOG  INT_IDEO  INT_MISC   INT_ANY
# eventid   -0.050527 -0.054506 -0.198305 -0.138062
# iyear     -0.050518 -0.054509 -0.198508 -0.138085
# imonth    -0.005129 -0.003555  0.036022  0.004690
# iday       0.013197  0.011646  0.016223  0.018901
# extended   0.025014  0.032679  0.033392  0.030944
# ...             ...       ...       ...       ...
# nreleased  0.013475  0.011796  0.024506  0.037916
# INT_LOG    1.000000  0.994879  0.114463  0.814948
# INT_IDEO   0.994879  1.000000  0.139247  0.817230
# INT_MISC   0.114463  0.139247  1.000000  0.380166
# INT_ANY    0.814948  0.817230  0.380166  1.000000
#
# [79 rows x 79 columns]

# %%
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %%
data.nunique()
# Out:
# eventid       171
# iyear          16
# imonth         13
# iday           32
# approxdate     19
#              ...
# INT_LOG         3
# INT_IDEO        3
# INT_MISC        3
# INT_ANY         3
# related       155
# Length: 135, dtype: int64

# %%
data.dtypes
# Out:
# eventid       float64
# iyear           int64
# imonth        float64
# iday          float64
# approxdate     object
#                ...
# INT_LOG       float64
# INT_IDEO      float64
# INT_MISC      float64
# INT_ANY       float64
# related        object
# Length: 135, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18913 entries, 0 to 18912
# Columns: 135 entries, eventid to related
# dtypes: float64(78), int64(1), object(56)
# memory usage: 19.5+ MB

# %%
data.isnull().sum()
# Out:
# eventid           0
# iyear             0
# imonth            1
# iday              1
# approxdate    18892
#               ...
# INT_LOG           1
# INT_IDEO          1
# INT_MISC          1
# INT_ANY           1
# related       18176
# Length: 135, dtype: int64

# %%
data['nkill']=data['nkill'].fillna(0)
data['nwound']=data['nwound'].fillna(0)

# %%
data['Casualities'] = data['nkill'] + data['nwound']

# %%
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             1
# iday               1
# approxdate     18892
#                ...
# INT_IDEO           1
# INT_MISC           1
# INT_ANY            1
# related        18176
# Casualities        0
# Length: 136, dtype: int64

# %% [markdown]
# **Data visualization**

# %%
year = data['iyear'].unique()
years_count = data['iyear'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (15,10))
sns.barplot(x = year, y = years_count, palette = 'tab10')
plt.xticks(rotation = 50)
plt.xlabel('Attacking Year',fontsize=20)
plt.ylabel('Number of Attacks Each Year',Fontsize=20)
plt.title('Attacks In Years',fontsize=22)
plt.show()

# %% [markdown]
# here The graph shows the number of Attacks in each year from 1970 to 1992 and here we observed that the number of global terrorism attacks are continuously increasing from 1988 . The Graph shows 1991 is the most unlucky year because the most number of attacks took place in the year 1991.

# %%
Data = data[['iyear','nkill']].groupby(['iyear']).sum()
fig, ax4 = plt.subplots(figsize=(20,10))
Data.plot(kind='bar',alpha=0.7,ax=ax4, color="green")
plt.xticks(rotation = 50)
plt.title("People Died Due To Attack",fontsize=25)
plt.ylabel("Number of killed peope",fontsize=20)
plt.xlabel('Year',fontsize=20)
top_side = ax4.spines["top"]
top_side.set_visible(False)
right_side = ax4.spines["right"]
right_side.set_visible(False)

# %% [markdown]
# The graph shows the number of people killed from the year 1970 to 1992. As number of attacks increases, the people killed in attacks is also increases. The number of killed people is atmost in 1984.

# %%
data['gname'].value_counts().to_frame().drop('Unknown').head(10).plot(kind='bar',color='yellow',figsize=(20,10))
plt.title("Top 10 terrorist group attack",fontsize=25)
plt.xlabel("terrorist group name",fontsize=20)
plt.ylabel("Attack number",fontsize=20)
plt.show()

# %% [markdown]
# Here the graph shows the top 10 terrorist group attacks and Taliban is the most active terrorist group followed by the others.

# %%
data['country_txt'].value_counts().to_frame().sort_values('country_txt',axis=0,ascending=False).head(10).plot(kind='bar',color='blue',figsize=(20,10))
plt.title("Top 10 Attacked Countries",fontsize=25)
plt.xticks(rotation = 50)
plt.xlabel("Country Name",fontsize=20)
plt.ylabel("Attack number",fontsize=20)
plt.show()

# %%
data['attacktype1_txt'].value_counts().plot(kind='bar',figsize=(20,10),color='orange')
plt.xticks(rotation = 50)
plt.xlabel("Attack Type",fontsize=20)
plt.ylabel("Number of attack",fontsize=20)
plt.title("Name of attacktype",fontsize=25)
plt.show()

# %% [markdown]
# The Graph shows that which type of attack is mostly used. Here we observed that the Bombing/Explosion type attack were used most of time.

# %%
plt.subplots(figsize=(20,10))
sns.countplot(data["targtype1_txt"],order=data['targtype1_txt'].value_counts().index,palette="gist_heat",edgecolor=sns.color_palette("Set2"));
plt.xticks(rotation=90)
plt.xlabel("Attacktype",fontsize=20)
plt.ylabel("count",fontsize=20)
plt.title("Type of attack",fontsize=25)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
kill = data.loc[:,'nkill']
print('Number of people killed by terror attack:', int(sum(kill.dropna())))
# Out:
# Number of people killed by terror attack: 25705

# %%
data1 = data.pivot_table(columns='attacktype1_txt', values='nkill', aggfunc='sum')
data1
# Out:
# attacktype1_txt  Armed Assault  Assassination  Bombing/Explosion  \
# nkill                  13749.0         3944.0             5350.0
#
# attacktype1_txt  Facility/Infrastructure Attack  Hijacking  \
# nkill                                     591.0      186.0
#
# attacktype1_txt  Hostage Taking (Barricade Incident)  \
# nkill                                          240.0
#
# attacktype1_txt  Hostage Taking (Kidnapping)  Unarmed Assault  Unknown
# nkill                                  389.0             19.0   1237.0

# %%
data1 = data.pivot_table(columns='country', values='nkill', aggfunc='sum')
data1
# Out:
# country  4.0    5.0    6.0    7.0    8.0    11.0   14.0   15.0   17.0   18.0   \
# nkill     53.0    0.0    0.0    0.0  134.0  329.0    6.0   12.0    0.0    0.0
#
# country  ...  362.0  377.0  403.0  406.0  428.0  499.0  532.0   603.0  604.0  \
# nkill    ...   68.0    3.0  217.0    0.0   81.0    1.0    0.0  2060.0    1.0
#
# country  605.0
# nkill     15.0
#
# [1 rows x 129 columns]

# %%
attack = data.country.value_counts()[:8]
attack
# Out:
# 61.0     2551
# 603.0    2090
# 217.0    1712
# 185.0    1375
# 98.0     1226
# 83.0     1194
# 45.0     1051
# 159.0     781
# 69.0      781
# 209.0     593
# 145.0     562
# 110.0     512
# 97.0      399
# 94.0      378
# 362.0     354
# 11.0      354
# 160.0     264
# 78.0      202
# 43.0      179
# 155.0     165
# 183.0     145
# 200.0     134
# 130.0     125
# 26.0       92
# 92.0       84
# 403.0      83
# 88.0       80
# 101.0      79
# 162.0      77
# 205.0      73
# 30.0       65
# 199.0      60
# 222.0      56
# 96.0       55
# 21.0       49
# 139.0      49
# 218.0      48
# 15.0       43
# 59.0       41
# 49.0       41
# 231.0      40
# 213.0      40
# 142.0      33
# 153.0      31
# 102.0      29
# 65.0       29
# 138.0      26
# 14.0       24
# 95.0       23
# 60.0       22
# 137.0      22
# 499.0      21
# 53.0       20
# 111.0      18
# 58.0       16
# 38.0       16
# 156.0      15
# 106.0      13
# 8.0        12
# Name: country, dtype: int64

# %%
data.gname.value_counts()[1:11]
# Out:
# Irish Republican Army (IRA)                         1333
# Farabundo Marti National Liberation Front (FMLN)     779
# Basque Fatherland and Freedom (ETA)                  769
# Shining Path (SL)                                    536
# Palestinians                                         420
# Revolutionary Armed Forces of Colombia (FARC)        310
# M-19 (Movement of April 19)                          259
# Protestant extremists                                220
# Red Brigades                                         209
# Sandinista National Liberation Front (FSLN)          197
# Name: gname, dtype: int64

# %% [markdown]
# **Summury**
#
# Highest number of attacks took place in 2014.
#
# Leading to highest death rate in that year.
#
# Taliban has done the hightest number of attacks out of all terrorist groups.
#
# The highest number of attacks took place in Iraq.
#
# The most frequent attack types were bombing/explosion.
#
# These attacks affected provate citizens and propertiest the most
